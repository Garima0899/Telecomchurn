# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 5
#       3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
# ----> 5 from scipy import statistics
#
# ImportError: cannot import name 'statistics' from 'scipy' (C:\ProgramData\anaconda3\Lib\site-packages\scipy\__init__.py)

# %%
gd = pd.read_csv(r"C:\Users\hp\Downloads\telecom_churn.csv")
gd
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
gd.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
gd.head(10)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
# 5    AL             118        510                Yes              No
# 6    MA             121        510                 No             Yes
# 7    MO             147        415                Yes              No
# 8    LA             117        408                 No              No
# 9    WV             141        415                Yes             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# ...

# %% [raw]
# #Churn : the percentage of subscribers who end their contract or subscription with a telecom company within a specific time period
# what is the proportion of churned users in our dataframe?

# %%
gd['Churn'].value_counts()
# Out:
# Churn
# False    2850
# True      483
# Name: count, dtype: int64

# %%
gd['Churn'].value_counts(normalize = True)  #we will get % of churned ppl by using normalize
# Out:
# Churn
# False    0.855086
# True     0.144914
# Name: proportion, dtype: float64

# %%
gd['Churn'].replace({False:0, True:1},inplace = True)
gd
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
gd['Churn'].mean()  #14.5% is actually quite bad for a company; such a churn rate can make the company go bankrupt.
# Out:
# 0.14491449144914492

# %% [raw]
# What are average values of numerical features for churned users?

# %%
gd.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
gd[gd['Churn']== 1].mean(numeric_only= True)
# Out:
# Account length            102.664596
# Area code                 437.817805
# Number vmail messages       5.115942
# Total day minutes         206.914079
# Total day calls           101.335404
# Total day charge           35.175921
# Total eve minutes         212.410145
# Total eve calls           100.561077
# Total eve charge           18.054969
# Total night minutes       205.231677
# Total night calls         100.399586
# Total night charge          9.235528
# Total intl minutes         10.700000
# Total intl calls            4.163561
# Total intl charge           2.889545
# Customer service calls      2.229814
# Churn                       1.000000
# dtype: float64

# %% [raw]
# How much time (on average) do churned users spend on the phone during daytime?

# %%
gd.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
gd[gd['Churn']== 1]['Total day minutes'].mean(numeric_only= True)
# Out:
# 206.91407867494823

# %% [raw]
# what is the maximum length of international calls among loyal users (Churn == 0) who do not have an international plan?

# %%
gd[(gd['International plan']== 'No') & (gd['Churn']==0)][['Total intl minutes']].max()
# Out:
# Total intl minutes    18.9
# dtype: float64

# %% [raw]
# How do the usage patterns (day, evening, night, and international minutes) differ between customers who churn and those who do not?

# %%
churned=gd[gd['Churn']==1]
non_churned=gd[gd['Churn']==0]
usage_parameters=['Total day minutes','Total eve minutes','Total night minutes']
avg_usage_churned=churned[usage_parameters].mean()
avg_usage_non_churned=non_churned[usage_parameters].mean()
average_usage = pd.DataFrame({'Churned' : avg_usage_churned,'Non_Churned' : avg_usage_non_churned })
average_usage
# Out:
#                         Churned  Non_Churned
# Total day minutes    206.914079   175.175754
# Total eve minutes    212.410145   199.043298
# Total night minutes  205.231677   200.133193

# %% [raw]
# Are there any notable differences in the number of customer service calls between churned and non-churned customers?

# %%
gd.groupby(['Churn'])['Customer service calls'].sum()
# Out:
# Churn
# 0    4132
# 1    1077
# Name: Customer service calls, dtype: int64
